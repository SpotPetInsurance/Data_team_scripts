# %%
library(bigrquery)
library(dplyr)
projectid = "spot-pet-production"

sql <- "SELECT  * FROM `spot-pet-production.data_exceptions.Check_CF_Data`"

# Run the query and store the data in a tibble
tb <- bq_project_query(projectid, sql)


database_data <- bq_table_download(tb)
database_data <- as.data.frame(database_data)

sql1 <- "SELECT  * FROM `spot-pet-production.data_exceptions.database_copy_time`"

tb1 <- bq_project_query(projectid, sql1)


refresh_data <- bq_table_download(tb1)
refresh_data <- as.data.frame(refresh_data)

currentDate <- Sys.Date()


if (database_data$test_cf_data == "TRUE" & currentDate > refresh_data$day_of_copy ) {

    sql <- "select * from `spot-pet-production.funnel_exec_dash.all_funnel_data_view_int`"
    tb <- bq_project_query(projectid, sql)
    database_data <- bq_table_download(tb)
    dataset_name <- 'copy_of_exec_dash_20'
    partnerize_table = bq_table(project = projectid, dataset = dataset_name, table = 'all_funnel_data_view_int_copy')
    bq_table_upload(x=partnerize_table, values= database_data, create_disposition='CREATE_IF_NEEDED', write_disposition='WRITE_TRUNCATE')
    
    sql <- "select * from `spot-pet-production.data_warehouse.Calls_data_for_Dash`"
    tb <- bq_project_query(projectid, sql)
    database_data <- bq_table_download(tb)
    dataset_name <- 'copy_of_exec_dash_20'
    partnerize_table = bq_table(project = projectid, dataset = dataset_name, table = 'Calls_data_for_Dash_copy')
    bq_table_upload(x=partnerize_table, values= database_data, create_disposition='CREATE_IF_NEEDED', write_disposition='WRITE_TRUNCATE')
    
    sql <- "select * from `spot-pet-production.exec_dash_canada.canada_exec_dash`"
    tb <- bq_project_query(projectid, sql)
    database_data <- bq_table_download(tb)
    dataset_name <- 'copy_of_exec_dash_20'
    partnerize_table = bq_table(project = projectid, dataset = dataset_name, table = 'canada_exec_dash_copy')
    bq_table_upload(x=partnerize_table, values= database_data, create_disposition='CREATE_IF_NEEDED', write_disposition='WRITE_TRUNCATE')
    
    sql <- "select * from `spot-pet-production.data_warehouse.cf_calls_data_set1`"
    tb <- bq_project_query(projectid, sql)
    database_data <- bq_table_download(tb)
    dataset_name <- 'copy_of_exec_dash_20'
    partnerize_table = bq_table(project = projectid, dataset = dataset_name, table = 'cf_calls_data_set1_copy')
    bq_table_upload(x=partnerize_table, values= database_data, create_disposition='CREATE_IF_NEEDED', write_disposition='WRITE_TRUNCATE')
    
    sql <- "select * from `spot-pet-production.funnel_exec_dash.cf_daily_metrics`"
    tb <- bq_project_query(projectid, sql)
    database_data <- bq_table_download(tb)
    dataset_name <- 'copy_of_exec_dash_20'
    partnerize_table = bq_table(project = projectid, dataset = dataset_name, table = 'cf_daily_metrics_copy')
    bq_table_upload(x=partnerize_table, values= database_data, create_disposition='CREATE_IF_NEEDED', write_disposition='WRITE_TRUNCATE')
    
    sql <- "select * from `spot-pet-production.funnel_exec_dash.Claims_Reimbursement`"
    tb <- bq_project_query(projectid, sql)
    database_data <- bq_table_download(tb)
    dataset_name <- 'copy_of_exec_dash_20'
    partnerize_table = bq_table(project = projectid, dataset = dataset_name, table = 'Claims_Reimbursement_copy')
    bq_table_upload(x=partnerize_table, values= database_data, create_disposition='CREATE_IF_NEEDED', write_disposition='WRITE_TRUNCATE')
    
    sql <- "select * from `spot-pet-production.multi_touch_att.policy_markov_cost`"
    tb <- bq_project_query(projectid, sql)
    database_data <- bq_table_download(tb)
    dataset_name <- 'copy_of_exec_dash_20'
    partnerize_table = bq_table(project = projectid, dataset = dataset_name, table = 'policy_markov_cost_copy')
    bq_table_upload(x=partnerize_table, values= database_data, create_disposition='CREATE_IF_NEEDED', write_disposition='WRITE_TRUNCATE')
    
    sql <- "select * from `spot-pet-production.multi_touch_att.quote_markov_cost`"
    tb <- bq_project_query(projectid, sql)
    database_data <- bq_table_download(tb)
    dataset_name <- 'copy_of_exec_dash_20'
    partnerize_table = bq_table(project = projectid, dataset = dataset_name, table = 'quote_markov_cost_copy')
    bq_table_upload(x=partnerize_table, values= database_data, create_disposition='CREATE_IF_NEEDED', write_disposition='WRITE_TRUNCATE')
    
    sql <- "select * from `spot-pet-production.funnel_exec_dash.unique_quoters_by_day`"
    tb <- bq_project_query(projectid, sql)
    database_data <- bq_table_download(tb)
    dataset_name <- 'copy_of_exec_dash_20'
    partnerize_table = bq_table(project = projectid, dataset = dataset_name, table = 'unique_quoters_by_day_copy')
    bq_table_upload(x=partnerize_table, values= database_data, create_disposition='CREATE_IF_NEEDED', write_disposition='WRITE_TRUNCATE')
    
    
    sql2 <- "truncate table `spot-pet-production.data_exceptions.database_copy_time`"
    tb <- bq_project_query(projectid, sql2)
    
    sql3 <- "INSERT INTO `spot-pet-production.data_exceptions.database_copy_time` (day_of_copy) VALUES (DATE(CURRENT_TIMESTAMP(), 'America/New_York'))"
    tb <- bq_project_query(projectid, sql3)
        
}
# Out:
# Auto-refreshing stale OAuth token.
